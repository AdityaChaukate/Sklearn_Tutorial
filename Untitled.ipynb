# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

df = pd.read_csv("cgpa_vs_placement_package_50.csv")
df.head()
# Out:
#    CGPA  Placement_Package_LPA
# 0  5.00                  25.99
# 1  5.10                  25.73
# 2  5.20                  28.34
# 3  5.31                  31.24
# 4  5.41                  28.80

# %%
df.isnull().sum()
# Out:
# CGPA                     0
# Placement_Package_LPA    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
x = df[["CGPA"]]
y = df["Placement_Package_LPA"]

plt.figure(figsize = (5,4))
graph = plt.plot(x,y , marker = "o")
plt.xlabel("CGPA")
plt.ylabel("Placement_Package_LPA")
plt.title("CGPA vs packages")

plt.grid()
plt.show()

# %%
graph = plt.scatter(x,y)
plt.xlabel("CGPA")
plt.ylabel("Placement_Package_LPA")
plt.title("CGPA vs packages")
plt.plot(x,y_predict)
plt.grid()
plt.show()

# %%
x = df[["CGPA"]]
y = df["Placement_Package_LPA"]

x_train, x_test , y_train, y_test = train_test_split(x,y,test_size = 0.2 , random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
	28.34

# %%
lr.coef_
# Out:
# array([14.52809662])

# %%
lr.intercept_
# Out:
# np.float64(-50.76796259758518)

# %%
y = 14.52809662* x -50.76796259758518

# %%
lr.score(x_test , y_test)*100
# Out:
# 98.7876323392597

# %%
y_predict = lr.predict(x)

# %%
graph = plt.scatter(x,y)
plt.xlabel("CGPA")
plt.ylabel("Placement_Package_LPA")
plt.title("CGPA vs packages")
plt.plot(x,y_predict , color = "red" , label = "predict")
plt.grid()
plt.legend(["org" , "predict Line"])
plt.show()
